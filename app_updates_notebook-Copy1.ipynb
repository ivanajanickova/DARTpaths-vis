# %% [markdown]
# # Visualisation & Application

# %% [markdown]
# ## Needed packages:

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import dash
import dash_cytoscape as cyto
import dash_bootstrap_components as dbc
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import json
from time import perf_counter
import coordinates
import db_retrieve

# %% [markdown]
# ## Some function:
# * to expand a dataframe
# * to load the dataframe into a graph

# %% [markdown]
# ### Expand the dataframe
# * wide dataframe
# * for every phenotype, the corresponding gene and ortholog

# %%
def expand_dataframe(df: pd.DataFrame):
    """Function to expand dataframe, so each phenotype is in a separate row.
    Returns new dataframe and the total number of genes

    :param df: dataframe to expand
    """
    df_1 = df.assign(phenotype=df['Enriched_Phenotypes'].astype(str).str.split(',')).explode('Enriched_Phenotypes')
    df_2 = df_1[['Orthlog_Genes', 'Human_Gene', 'Organism', 'Enriched_Phenotypes']]
    # get total number of genes
    n_genes = set(df['Human_Gene'].tolist())
    n = len(n_genes)  # total number of genes

    return df_2, n

# %% [markdown]
# ### Load the dataframe into a graph (nodes and edges)

# %%
def load_info_to_graph(dataframe: pd.DataFrame, metadata: pd.DataFrame, n_genes: int):
    """ Function used to extract information from dataframe and load it into
    nodes and edges list of dictionaries. For phenotype nodes, metadata is added as well

    :param dataframe: dataframe with information about nodes and edges
    :param metadata: dataframe with metadata of given pathway
    :param n_genes: number of unique genes, necessary for y position determination
    """

    # make nodes and edges
    nodes_list = []
    edges_list = []
    nodes_set = set()  # to avoid duplication

    # for node positions
    count_n = 1  # count for x_pos of gene nodes
    coordinates_ort = []
    coordinates_phenotype = []

    # Load data into nodes and edges
    for index, row in dataframe.iterrows():
        # source node is human gene
        gene = str(row['Human_Gene'])
        # target node is ortholog
        ortholog = str(row['Orthlog_Genes'])
        phenotype = str(row['Enriched_Phenotypes'])
        organism = str(row['Organism'])
        # add data and class info to the nodes
        # gene node positions
        # pos_x = 50  # always the same; set to 500 in case of large network
        pos_x, pos_y = coordinates.gene_coordinate(1, n_genes, count_n)
        cy_gene = {'data': {'id': gene,
                            'indent': 'gene',   #add
                            'label': gene,
                            'size': 4,
                            'fontsize': '1.5px'},
                   'classes': 'blue',
                   'selectable': True, #Allow selected
                   'position': {'x': pos_x, 'y': pos_y}}

        # ortholog node
        pos_x_ortholog, pos_y_ortholog = coordinates.check_coordinates(coordinates_ort, pos_y, n_genes, 20, 45, 55, 80)
        if ortholog != "NaN":
            cy_ortholog = {'data': {'id': ortholog,
                                    'label': ortholog,
                                    'indent': 'ortholog', #add
                                    'size': 2,
                                    'fontsize': '1px',
                                    'organism': organism},
                           'classes': 'ortholog', #add
                           'selectable': True,    #Allow selected
                           'position': {'x': pos_x_ortholog, 'y': pos_y_ortholog}}
            cy_edge = {
                'data': {'id': gene + ortholog,
                         'source': gene,
                         'target': ortholog,
                         'width': '0.25',
                         'color': '#696969'}}

        # add genes and orthologs to set nodes and cy nodes
        if gene not in nodes_set:
            nodes_set.add(gene)
            nodes_list.append(cy_gene)
            count_n += 1

        if ortholog not in nodes_set:
            nodes_set.add(ortholog)
            nodes_list.append(cy_ortholog)
        edges_list.append(cy_edge)

        if phenotype != "None": # get rid of None node
            metadata_phenotype = metadata.get(phenotype)  # load metadata
            # phenotype node
            pos_x_phenotype, pos_y_phenotype = coordinates.check_coordinates(coordinates_phenotype, pos_y, n_genes, 0, 20, 80, 100)

            cy_phenotype = {'data': {'id': phenotype,
                                     'label': phenotype,
                                     'indent': 'phenotype',
                                     'metadata': metadata_phenotype,
                                     'size': 1,
                                     'fontsize': '0.5px'},
                            'classes': 'purple',
                            'selectable': True,  #Allow selected
                            'grabbable': False,   #Not allow grab for now
                            'position': {'x': pos_x_phenotype, 'y': pos_y_phenotype}}
            cy_edge_2 = {'data': {'id': ortholog + phenotype,
                                  'source': ortholog,
                                  'target': phenotype,
                                  'width': '0.10',
                                  'color': '#B8B8B8'}}

            if phenotype not in nodes_set:
                nodes_set.add(phenotype)
                nodes_list.append(cy_phenotype)

            edges_list.append(cy_edge_2)
    return nodes_list, edges_list

# %% [markdown]
# ## Load Data:
# * The list of pathways we have so far:
#     * Phase2ConjugationOfCompounds (highest)
#     * Phase1CompundFunctionalization (1 level down)
#     * AmineOxidase (lowest)
#     * AminoAcidConjugation (lowest)
#     * EthanolOxidation (lowest)
#     * AHR (lowest)

# %%
# upper level
upper_df1 = db_retrieve.select_from_enrichment_results("Phase1CompundFunctionalization")
upper_df_1, upper_N_genes_1 = expand_dataframe(upper_df1)
metadata = db_retrieve.select_from_metadata("Phase1CompundFunctionalization")
# Out:
# Print each row and it's columns values
# PostgreSQL connection is closed
# PostgreSQL connection is closed

# %%
#AHR
gene_df1 = db_retrieve.select_from_enrichment_results("AHR")               #gene_df1 (type = pandas.core.frame.DataFrame)
gene_df_1, N_genes_1 = expand_dataframe(gene_df1) 
metadata1 = db_retrieve.select_from_metadata("AHR")                       #metadata1
# Out:
# Print each row and it's columns values
# PostgreSQL connection is closed
# PostgreSQL connection is closed

# %%
# example of dataframe
gene_df_1[1:10]
# Out:
#   Orthlog_Genes       Human_Gene       Organism  \
# 1         arnt2  ENSG00000172379      zebrafish
# 2           NaN  ENSG00000288622      zebrafish
# 3   FBgn0003513  ENSG00000063438  dmelanogaster
# 3   FBgn0003513  ENSG00000063438  dmelanogaster
# 3   FBgn0003513  ENSG00000063438  dmelanogaster
# 3   FBgn0003513  ENSG00000063438  dmelanogaster
# 3   FBgn0003513  ENSG00000063438  dmelanogaster
# 3   FBgn0003513  ENSG00000063438  dmelanogaster
# 3   FBgn0003513  ENSG00000063438  dmelanogaster
#
#                                  Enriched_Phenotypes
# 1                                               None
# 2                                               None
# 3                              abnormal neuroanatomy
# 3            abnormal neuroanatomy (with ss[D115.7])
# 3              abnormal neuroanatomy | somatic clone
# 3                        antenna (with ss[aBR30-71])
# 3                         chaeta (with ss[aBR30-71])
# 3  dendrite & dorsal multidendritic neuron ddaB |...
# 3  dendrite & dorsal multidendritic neuron ddaD |...

# %%
#AmineOxidase
gene_df2 = db_retrieve.select_from_enrichment_results("AmineOxidase")     #gene_df2
gene_df_2, N_genes_2 = expand_dataframe(gene_df2) 
metadata2 = db_retrieve.select_from_metadata("AmineOxidase")              #metadata2
# Out:
# Print each row and it's columns values
# PostgreSQL connection is closed
# PostgreSQL connection is closed

# %%
#AminoAcidConjugation
gene_df3 = db_retrieve.select_from_enrichment_results("AminoAcidConjugation")     #gene_df3
gene_df_3, N_genes_3 = expand_dataframe(gene_df3) 
metadata3 = db_retrieve.select_from_metadata("AminoAcidConjugation")              #metadata3
# Out:
# Print each row and it's columns values
# PostgreSQL connection is closed
# PostgreSQL connection is closed

# %%
#EthanolOxidation
gene_df4 = db_retrieve.select_from_enrichment_results("EthanolOxidation")     #gene_df4
gene_df_4, N_genes_4 = expand_dataframe(gene_df4) 
metadata4 = db_retrieve.select_from_metadata("EthanolOxidation")              #metadata4
# Out:
# Print each row and it's columns values
# PostgreSQL connection is closed
# PostgreSQL connection is closed

# %%
path_list = ['AHR', 'Amino Oxidase', 'Ethanol Oxidation', 'AminoAcid Conjugation']  #add

# %%
#nodes & edges
nodes, edges = load_info_to_graph(upper_df_1, metadata, upper_N_genes_1)
nodes1, edges1 = load_info_to_graph(gene_df_1, metadata1, N_genes_1)
nodes2, edges2 = load_info_to_graph(gene_df_2, metadata2, N_genes_2)
nodes3, edges3 = load_info_to_graph(gene_df_3, metadata3, N_genes_3)
nodes4, edges4 = load_info_to_graph(gene_df_4, metadata4, N_genes_4)

# %%
element = edges + nodes
new_element1 = edges1 + nodes1
new_element2 = edges2 + nodes2
new_element3 = edges3 + nodes3
new_element4 = edges4 + nodes4

# %%
nodes1
# Out:
# [{'data': {'id': 'ENSG00000143437',
#    'indent': 'gene',
#    'label': 'ENSG00000143437',
#    'size': 4,
#    'fontsize': '1.5px'},
#   'classes': 'blue',
#   'selectable': True,
#   'position': {'x': 50, 'y': 12.5}},
#  {'data': {'id': 'arnt',
#    'label': 'arnt',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 41.83495621677152, 'y': 48.064603068407585}},
#  {'data': {'id': 'ENSG00000172379',
#    'indent': 'gene',
#    'label': 'ENSG00000172379',
#    'size': 4,
#    'fontsize': '1.5px'},
#   'classes': 'blue',
#   'selectable': True,
#   'position': {'x': 50, 'y': 25.0}},
#  {'data': {'id': 'arnt2',
#    'label': 'arnt2',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 39.55501146034899, 'y': 64.72956443328935}},
#  {'data': {'id': 'ENSG00000288622',
#    'indent': 'gene',
#    'label': 'ENSG00000288622',
#    'size': 4,
#    'fontsize': '1.5px'},
#   'classes': 'blue',
#   'selectable': True,
#   'position': {'x': 50, 'y': 37.5}},
#  {'data': {'id': 'arnt2',
#    'label': 'arnt2',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 39.55501146034899, 'y': 64.72956443328935}},
#  {'data': {'id': 'ENSG00000063438',
#    'indent': 'gene',
#    'label': 'ENSG00000063438',
#    'size': 4,
#    'fontsize': '1.5px'},
#   'classes': 'blue',
#   'selectable': True,
#   'position': {'x': 50, 'y': 50.0}},
#  {'data': {'id': 'FBgn0003513',
#    'label': 'FBgn0003513',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'dmelanogaster'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 77.13848822869723, 'y': 80.33769421718459}},
#  {'data': {'id': 'abnormal neuroanatomy',
#    'label': 'abnormal neuroanatomy',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.008, 344.0, 0.076],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 5.627481996665919, 'y': 67.09365190368078}},
#  {'data': {'id': 'abnormal neuroanatomy (with ss[D115.7])',
#    'label': 'abnormal neuroanatomy (with ss[D115.7])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 86.0, 0.019],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 89.77826792041729, 'y': 9.85069063661741}},
#  {'data': {'id': 'abnormal neuroanatomy | somatic clone',
#    'label': 'abnormal neuroanatomy | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.042, 414.0, 0.091],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 9.285689694262276, 'y': 65.63242388578729}},
#  {'data': {'id': 'antenna (with ss[aBR30-71])',
#    'label': 'antenna (with ss[aBR30-71])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 123.0, 0.027],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 19.432706589325917, 'y': 21.84952843342185}},
#  {'data': {'id': 'chaeta (with ss[aBR30-71])',
#    'label': 'chaeta (with ss[aBR30-71])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 125.0, 0.027],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 16.332923979061945, 'y': 56.74315162587461}},
#  {'data': {'id': 'dendrite & dorsal multidendritic neuron ddaB | somatic clone',
#    'label': 'dendrite & dorsal multidendritic neuron ddaB | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 132.0, 0.029],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 82.44630120486359, 'y': 67.91909903178679}},
#  {'data': {'id': 'dendrite & dorsal multidendritic neuron ddaD | somatic clone',
#    'label': 'dendrite & dorsal multidendritic neuron ddaD | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 126.0, 0.028],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 16.138369874491303, 'y': 58.09278003023892}},
#  {'data': {'id': 'dendrite & dorsal multidendritic neuron ddaE',
#    'label': 'dendrite & dorsal multidendritic neuron ddaE',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 204.0, 0.045],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 96.57611949040046, 'y': 58.142064335803646}},
#  {'data': {'id': 'dendrite & dorsal multidendritic neuron ddaE (with ss[D115.7])',
#    'label': 'dendrite & dorsal multidendritic neuron ddaE (with ss[D115.7])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 127.0, 0.028],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 97.78937891183467, 'y': 52.88090515725861}},
#  {'data': {'id': 'dendrite & dorsal multidendritic neuron ddaE | somatic clone',
#    'label': 'dendrite & dorsal multidendritic neuron ddaE | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 205.0, 0.045],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 1.4586086826414335, 'y': 67.84925850350618}},
#  {'data': {'id': 'dendrite & dorsal multidendritic neuron ddaF | somatic clone',
#    'label': 'dendrite & dorsal multidendritic neuron ddaF | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 128.0, 0.028],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 8.56624851184852, 'y': 51.763680143086255}},
#  {'data': {'id': 'dendrite & lateral multidendritic neuron ldaB | somatic clone',
#    'label': 'dendrite & lateral multidendritic neuron ldaB | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 129.0, 0.028],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 13.831631585355531, 'y': 29.648407159095903}},
#  {'data': {'id': 'leg | ectopic (with ss[aBR30-71])',
#    'label': 'leg | ectopic (with ss[aBR30-71])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 79.0, 0.017],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 84.39072971365098, 'y': 59.089019593899295}},
#  {'data': {'id': 'lethal | recessive',
#    'label': 'lethal | recessive',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.065, 428.0, 0.094],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 92.43915285017347, 'y': 96.02026703700591}},
#  {'data': {'id': 'visible (with ss[aBR30-71])',
#    'label': 'visible (with ss[aBR30-71])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 131.0, 0.029],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 89.30146924574895, 'y': 60.93737344260241}},
#  {'data': {'id': 'chaeta (with ss[aP88])',
#    'label': 'chaeta (with ss[aP88])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 80.0, 0.018],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 95.09534599482305, 'y': 32.89987018314397}},
#  {'data': {'id': 'viable',
#    'label': 'viable',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 190.0, 0.042],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 98.57931322980318, 'y': 87.27501419556233}},
#  {'data': {'id': 'visible (with ss[aP88])',
#    'label': 'visible (with ss[aP88])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 115.0, 0.025],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 1.6819477879532263, 'y': 87.03246305987827}},
#  {'data': {'id': 'antenna',
#    'label': 'antenna',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.026, 396.0, 0.087],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 99.68017700104058, 'y': 25.24750595825297}},
#  {'data': {'id': 'visible | homeotic',
#    'label': 'visible | homeotic',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.008, 347.0, 0.076],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 90.60938402466529, 'y': 44.89036681377371}},
#  {'data': {'id': 'posterior vertical bristle',
#    'label': 'posterior vertical bristle',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.005, 311.0, 0.068],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 3.6042405194587457, 'y': 14.854324229354887}},
#  {'data': {'id': 'scutellar bristle',
#    'label': 'scutellar bristle',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.038, 413.0, 0.091],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 4.922567219060263, 'y': 43.965167215227986}},
#  {'data': {'id': 'vertical bristle',
#    'label': 'vertical bristle',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 233.0, 0.051],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 4.657088923635618, 'y': 1.0106599145352502}},
#  {'data': {'id': 'tarsal segment',
#    'label': 'tarsal segment',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.023, 389.0, 0.085],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 83.988315903672, 'y': 56.55752960232259}},
#  {'data': {'id': 'arista (with Df(3R)ss-D114.4)',
#    'label': 'arista (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 78.0, 0.017],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 91.2170179038605, 'y': 56.809627331897914}},
#  {'data': {'id': 'tarsal segment | ectopic (with Df(3R)ss-D114.4)',
#    'label': 'tarsal segment | ectopic (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 63.0, 0.014],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 98.11452507350371, 'y': 71.51383016417404}},
#  {'data': {'id': 'third segment of antenna (with Df(3R)ss-D114.4)',
#    'label': 'third segment of antenna (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 122.0, 0.027],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 14.399150185208187, 'y': 4.101935396305123}},
#  {'data': {'id': 'visible (with Df(3R)ss-D114.4)',
#    'label': 'visible (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 26.0, 0.006],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 99.33384340223222, 'y': 31.849889713384027}},
#  {'data': {'id': 'antennal disc (with Df(3R)ss-D114.4)',
#    'label': 'antennal disc (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 120.0, 0.026],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 89.07585527454769, 'y': 50.022515836671985}},
#  {'data': {'id': 'fifth segment of antenna (with Df(3R)ss-D114.4)',
#    'label': 'fifth segment of antenna (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 141.0, 0.031],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 94.72273770413366, 'y': 39.38806326106234}},
#  {'data': {'id': 'fourth segment of antenna (with Df(3R)ss-D114.4)',
#    'label': 'fourth segment of antenna (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 142.0, 0.031],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 6.609178177415352, 'y': 4.359249054043291}},
#  {'data': {'id': 'leg joint (with ss[a])',
#    'label': 'leg joint (with ss[a])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 143.0, 0.031],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 12.028272899180404, 'y': 9.986138869788608}},
#  {'data': {'id': 'leg | ectopic',
#    'label': 'leg | ectopic',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.003, 296.0, 0.065],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 6.940809493372601, 'y': 61.96723218299809}},
#  {'data': {'id': 'metatarsus (with ss[a])',
#    'label': 'metatarsus (with ss[a])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 144.0, 0.032],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 0.33109182394952974, 'y': 41.57872304325475}},
#  {'data': {'id': 'pretarsus (with ss[D115.7])',
#    'label': 'pretarsus (with ss[D115.7])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 145.0, 0.032],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 1.935872635561109, 'y': 5.418785394082737}},
#  {'data': {'id': 'second segment of antenna (with Df(3R)ss-D114.4)',
#    'label': 'second segment of antenna (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 146.0, 0.032],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 1.1566353345981661, 'y': 10.046727262423383}},
#  {'data': {'id': 'sex comb | ectopic (with ss[a])',
#    'label': 'sex comb | ectopic (with ss[a])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 147.0, 0.032],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 12.111886610120596, 'y': 17.01595920085768}},
#  {'data': {'id': 'tarsal segment 2 (with ss[D115.7])',
#    'label': 'tarsal segment 2 (with ss[D115.7])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 148.0, 0.033],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 88.83335928450856, 'y': 75.2120416972143}},
#  {'data': {'id': 'tarsal segment 3 (with ss[D115.7])',
#    'label': 'tarsal segment 3 (with ss[D115.7])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 149.0, 0.033],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 18.278313728120594, 'y': 51.57656606042204}},
#  {'data': {'id': 'tarsal segment 4 (with ss[D115.7])',
#    'label': 'tarsal segment 4 (with ss[D115.7])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 150.0, 0.033],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 12.580638583438077, 'y': 35.14270427557865}},
#  {'data': {'id': 'ventral thoracic disc (with ss[D115.7])',
#    'label': 'ventral thoracic disc (with ss[D115.7])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 135.0, 0.03],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 1.9380837737393053, 'y': 56.14341707279878}},
#  {'data': {'id': 'visible',
#    'label': 'visible',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.031, 406.0, 0.089],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 15.425229143794308, 'y': 1.4941379388216491}},
#  {'data': {'id': 'visible (with ss[D115.7])',
#    'label': 'visible (with ss[D115.7])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 134.0, 0.029],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 16.974016746194913, 'y': 40.500720406869625}},
#  {'data': {'id': 'abnormal neuroanatomy (with ss[134])',
#    'label': 'abnormal neuroanatomy (with ss[134])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 133.0, 0.029],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 97.692769412883, 'y': 88.69476769874836}},
#  {'data': {'id': 'antennal sense organ',
#    'label': 'antennal sense organ',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.006, 321.0, 0.071],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 10.361466719633443, 'y': 98.59703812039962}},
#  {'data': {'id': 'dendrite & dorsal multidendritic neuron ddaC | somatic clone',
#    'label': 'dendrite & dorsal multidendritic neuron ddaC | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.003, 278.0, 0.061],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 93.8033946857042, 'y': 61.759239746925196}},
#  {'data': {'id': 'dendrite & dorsal multidendritic neuron ddaE (with ss[134])',
#    'label': 'dendrite & dorsal multidendritic neuron ddaE (with ss[134])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 124.0, 0.027],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 93.59226713208723, 'y': 78.6655861275978}},
#  {'data': {'id': 'dorsomedial papilla',
#    'label': 'dorsomedial papilla',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 217.0, 0.048],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 97.55185446311131, 'y': 10.519907068142375}},
#  {'data': {'id': 'leg',
#    'label': 'leg',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.065, 425.0, 0.093],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 3.371333882883387, 'y': 2.1721533580797314}},
#  {'data': {'id': 'maxillary palpus',
#    'label': 'maxillary palpus',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.008, 343.0, 0.075],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 80.15603033154282, 'y': 21.413824955848217}},
#  {'data': {'id': 'metatarsus',
#    'label': 'metatarsus',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.004, 304.0, 0.067],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 6.958227789258464, 'y': 59.84479373458097}},
#  {'data': {'id': 'pale ommatidium | ectopic',
#    'label': 'pale ommatidium | ectopic',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 118.0, 0.026],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 89.44542685716888, 'y': 58.66927715326034}},
#  {'data': {'id': 'pale ommatidium | ectopic | somatic clone',
#    'label': 'pale ommatidium | ectopic | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 119.0, 0.026],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 19.528295564872575, 'y': 60.05750777304469}},
#  {'data': {'id': 'photoreceptor cell R7 of pale ommatidium | ectopic | somatic clone',
#    'label': 'photoreceptor cell R7 of pale ommatidium | ectopic | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 121.0, 0.027],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 99.8162391596208, 'y': 66.1489836796995}},
#  {'data': {'id': 'photoreceptor cell R7 of yellow ommatidium | somatic clone',
#    'label': 'photoreceptor cell R7 of yellow ommatidium | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 27.0, 0.006],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 8.158988886724881, 'y': 57.96641246102885}},
#  {'data': {'id': 'pretarsus (with ss[D114.9])',
#    'label': 'pretarsus (with ss[D114.9])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 28.0, 0.006],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 93.90068611172642, 'y': 97.94460353035028}},
#  {'data': {'id': 'pretarsus | ectopic (with Df(3R)ss-D114.4)',
#    'label': 'pretarsus | ectopic (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 29.0, 0.006],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 10.041092403034462, 'y': 52.722122104076185}},
#  {'data': {'id': 'tarsal segment (with Df(3R)ss-D114.4)',
#    'label': 'tarsal segment (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 11.0, 0.002],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 91.98647531326242, 'y': 15.911339576758088}},
#  {'data': {'id': 'tarsal segment 2',
#    'label': 'tarsal segment 2',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.004, 307.0, 0.067],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 19.392150706079722, 'y': 4.755173390602064}},
#  {'data': {'id': 'tarsal segment 2 (with ss[D114.9])',
#    'label': 'tarsal segment 2 (with ss[D114.9])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 12.0, 0.003],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 92.82561305016137, 'y': 95.42400385472705}},
#  {'data': {'id': 'tarsal segment 3',
#    'label': 'tarsal segment 3',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.006, 325.0, 0.071],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 17.53052816180578, 'y': 65.38351962001425}},
#  {'data': {'id': 'tarsal segment 3 (with ss[D114.9])',
#    'label': 'tarsal segment 3 (with ss[D114.9])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 22.0, 0.005],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 83.30728325998133, 'y': 35.91135533509462}},
#  {'data': {'id': 'tarsal segment 4',
#    'label': 'tarsal segment 4',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.007, 336.0, 0.074],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 98.82454097737893, 'y': 16.376777944574407}},
#  {'data': {'id': 'tarsal segment 4 (with ss[D114.9])',
#    'label': 'tarsal segment 4 (with ss[D114.9])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 15.0, 0.003],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 6.644806779158716, 'y': 54.29165392795065}},
#  {'data': {'id': 'unguis | ectopic (with Df(3R)ss-D114.4)',
#    'label': 'unguis | ectopic (with Df(3R)ss-D114.4)',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 16.0, 0.004],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 19.271403222116263, 'y': 36.27557033880565}},
#  {'data': {'id': 'ventral thoracic disc (with ss[D114.9])',
#    'label': 'ventral thoracic disc (with ss[D114.9])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 17.0, 0.004],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 8.404519895409821, 'y': 64.71933632893744}},
#  {'data': {'id': 'visible (with ss[D114.9])',
#    'label': 'visible (with ss[D114.9])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 18.0, 0.004],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 93.8496685503824, 'y': 16.33841437005341}},
#  {'data': {'id': 'yellow ommatidium',
#    'label': 'yellow ommatidium',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 202.0, 0.044],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 3.699094006978454, 'y': 24.927676355339646}},
#  {'data': {'id': 'yellow ommatidium | somatic clone',
#    'label': 'yellow ommatidium | somatic clone',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 19.0, 0.004],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 3.852698612154253, 'y': 4.78249499483705}},
#  {'data': {'id': 'trichogen cell, with Scer\\GAL4[pnr-MD237]',
#    'label': 'trichogen cell, with Scer\\GAL4[pnr-MD237]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.058, 422.0, 0.093],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 89.93027522263345, 'y': 12.575509791609896}},
#  {'data': {'id': 'viable, with Dcr-2[UAS.cDa], Scer\\GAL4[elav.PLu]',
#    'label': 'viable, with Dcr-2[UAS.cDa], Scer\\GAL4[elav.PLu]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.004, 297.0, 0.065],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 10.30199945323468, 'y': 94.11584503519501}},
#  {'data': {'id': 'viable, with Scer\\GAL4[Mef2.PR]',
#    'label': 'viable, with Scer\\GAL4[Mef2.PR]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.002, 248.0, 0.055],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 15.148251366377856, 'y': 62.19897402118973}},
#  {'data': {'id': 'viable, with Scer\\GAL4[pnr-MD237]',
#    'label': 'viable, with Scer\\GAL4[pnr-MD237]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.069, 430.0, 0.095],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 94.35674090154414, 'y': 46.98655384396704}},
#  {'data': {'id': 'viable, with Scer\\GAL4[tin.CΔ4]',
#    'label': 'viable, with Scer\\GAL4[tin.CΔ4]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.02, 383.0, 0.084],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 15.883907572952609, 'y': 90.51946733514866}},
#  {'data': {'id': 'abnormal gravitaxis',
#    'label': 'abnormal gravitaxis',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.009, 354.0, 0.078],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 13.477971231848693, 'y': 2.671120059138987}},
#  {'data': {'id': 'arista',
#    'label': 'arista',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.027, 398.0, 0.087],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 7.045561655772483, 'y': 78.6134118152697}},
#  {'data': {'id': 'abnormal neuroanatomy, with Scer\\GAL4[477]',
#    'label': 'abnormal neuroanatomy, with Scer\\GAL4[477]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.003, 280.0, 0.062],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 98.20247579011576, 'y': 58.005142549065006}},
#  {'data': {'id': 'abnormal neuroanatomy, with Scer\\GAL4[ppk.PG]',
#    'label': 'abnormal neuroanatomy, with Scer\\GAL4[ppk.PG]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.01, 357.0, 0.078],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 1.1715214421089204, 'y': 69.32762156500992}},
#  {'data': {'id': 'dendrite & dorsal multidendritic neuron ddaC, with Scer\\GAL4[ppk.PG]',
#    'label': 'dendrite & dorsal multidendritic neuron ddaC, with Scer\\GAL4[ppk.PG]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 20.0, 0.004],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 0.20292834027573425, 'y': 54.046467865262194}},
#  {'data': {'id': 'dendrite & tracheal innervating neuron, with Scer\\GAL4[477]',
#    'label': 'dendrite & tracheal innervating neuron, with Scer\\GAL4[477]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 21.0, 0.005],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 16.56941680578856, 'y': 34.27140726160346}},
#  {'data': {'id': 'denticle belt | medial, with Scer\\GAL4[69B]',
#    'label': 'denticle belt | medial, with Scer\\GAL4[69B]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 39.0, 0.009],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 82.30006891339164, 'y': 14.36308264423346}},
#  {'data': {'id': 'eye photoreceptor cell | heat sensitive, with Scer\\GAL4[hs.PB]',
#    'label': 'eye photoreceptor cell | heat sensitive, with Scer\\GAL4[hs.PB]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 41.0, 0.009],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 2.337079955119008, 'y': 40.71762806597714}},
#  {'data': {'id': 'eye photoreceptor cell, with Scer\\GAL4[GMR.PF]',
#    'label': 'eye photoreceptor cell, with Scer\\GAL4[GMR.PF]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.014, 369.0, 0.081],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 17.958896743448715, 'y': 4.920499835389669}},
#  {'data': {'id': 'eye photoreceptor cell, with Scer\\GAL4[GMR.long]',
#    'label': 'eye photoreceptor cell, with Scer\\GAL4[GMR.long]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.002, 258.0, 0.057],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 11.29026650389428, 'y': 45.801149953050626}},
#  {'data': {'id': 'eye, with Scer\\GAL4[GMR.long]',
#    'label': 'eye, with Scer\\GAL4[GMR.long]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.007, 334.0, 0.073],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 0.0032538724109398842, 'y': 84.39797935284214}},
#  {'data': {'id': 'femur | distal',
#    'label': 'femur | distal',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 10.0, 0.002],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 2.4130961528358252, 'y': 43.81441548934396}},
#  {'data': {'id': 'increased cell death | cell autonomous | somatic clone, with Scer\\GAL4[Act5C.PI]',
#    'label': 'increased cell death | cell autonomous | somatic clone, with Scer\\GAL4[Act5C.PI]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 9.0, 0.002],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 93.86349359774572, 'y': 69.53856404188483}},
#  {'data': {'id': 'increased cell death | cell non-autonomous | somatic clone, with Scer\\GAL4[Act5C.PI]',
#    'label': 'increased cell death | cell non-autonomous | somatic clone, with Scer\\GAL4[Act5C.PI]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 8.0, 0.002],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 92.89102602632269, 'y': 93.32160756243798}},
#  {'data': {'id': 'leg anterior compartment',
#    'label': 'leg anterior compartment',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.002, 250.0, 0.055],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 15.026667369190339, 'y': 60.61045385998774}},
#  {'data': {'id': 'leg | distal, with Scer\\GAL4[ptc-559.1]',
#    'label': 'leg | distal, with Scer\\GAL4[ptc-559.1]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 30.0, 0.007],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 16.231948723179737, 'y': 68.94718514590394}},
#  {'data': {'id': 'lethal | heat sensitive, with Scer\\GAL4[hs.PB]',
#    'label': 'lethal | heat sensitive, with Scer\\GAL4[hs.PB]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.003, 293.0, 0.064],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 18.796833764729865, 'y': 31.787533698745875}},
#  {'data': {'id': 'maxillary palpus, with Scer\\GAL4[ptc-559.1]',
#    'label': 'maxillary palpus, with Scer\\GAL4[ptc-559.1]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 31.0, 0.007],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 11.649427523069388, 'y': 88.7694978598824}},
#  {'data': {'id': 'ommatidium, with Scer\\GAL4[GMR.long]',
#    'label': 'ommatidium, with Scer\\GAL4[GMR.long]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.003, 292.0, 0.064],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 2.8449432344028924, 'y': 78.06821314000413}},
#  {'data': {'id': 'photoreceptor cell R7 of pale ommatidium | heat sensitive, with Scer\\GAL4[hs.PB]',
#    'label': 'photoreceptor cell R7 of pale ommatidium | heat sensitive, with Scer\\GAL4[hs.PB]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 33.0, 0.007],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 88.2798159184962, 'y': 69.0478971334994}},
#  {'data': {'id': 'photoreceptor cell R7 of pale ommatidium, with Scer\\GAL4[GMR.PF]',
#    'label': 'photoreceptor cell R7 of pale ommatidium, with Scer\\GAL4[GMR.PF]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 40.0, 0.009],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 92.51363208249644, 'y': 35.024659936767755}},
#  {'data': {'id': 'photoreceptor cell R7 of pale ommatidium, with Scer\\GAL4[Pan-R7]',
#    'label': 'photoreceptor cell R7 of pale ommatidium, with Scer\\GAL4[Pan-R7]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 34.0, 0.007],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 19.166516788869963, 'y': 68.93032015433695}},
#  {'data': {'id': 'photoreceptor cell R7 of yellow ommatidium | ectopic | heat sensitive, with Scer\\GAL4[hs.PB]',
#    'label': 'photoreceptor cell R7 of yellow ommatidium | ectopic | heat sensitive, with Scer\\GAL4[hs.PB]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 35.0, 0.008],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 84.59405109682132, 'y': 24.19654078855823}},
#  {'data': {'id': 'photoreceptor cell R7 of yellow ommatidium | ectopic, with Scer\\GAL4[GMR.PF]',
#    'label': 'photoreceptor cell R7 of yellow ommatidium | ectopic, with Scer\\GAL4[GMR.PF]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 36.0, 0.008],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 6.976579217206524, 'y': 88.77136652198259}},
#  {'data': {'id': 'photoreceptor cell R7 of yellow ommatidium | ectopic, with Scer\\GAL4[Pan-R7]',
#    'label': 'photoreceptor cell R7 of yellow ommatidium | ectopic, with Scer\\GAL4[Pan-R7]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 37.0, 0.008],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 15.399088702714966, 'y': 46.342380496834664}},
#  {'data': {'id': 'rostral membrane, with Scer\\GAL4[ptc-559.1]',
#    'label': 'rostral membrane, with Scer\\GAL4[ptc-559.1]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 38.0, 0.008],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 86.00084857562867, 'y': 59.760121706391665}},
#  {'data': {'id': 'tergite, with Scer\\GAL4[ptc-559.1]',
#    'label': 'tergite, with Scer\\GAL4[ptc-559.1]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 24.0, 0.005],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 2.0431466062536785, 'y': 29.125925936380103}},
#  {'data': {'id': 'tibia, with Scer\\GAL4[ptc-559.1]',
#    'label': 'tibia, with Scer\\GAL4[ptc-559.1]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 25.0, 0.005],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 93.36888233010802, 'y': 4.323301145217073}},
#  {'data': {'id': 'tracheal branch primordium, with Scer\\GAL4[69B]',
#    'label': 'tracheal branch primordium, with Scer\\GAL4[69B]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 195.0, 0.043],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 17.94954268273033, 'y': 53.17990891850791}},
#  {'data': {'id': 'wing disc | cell autonomous | somatic clone, with Scer\\GAL4[Act5C.PI]',
#    'label': 'wing disc | cell autonomous | somatic clone, with Scer\\GAL4[Act5C.PI]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 32.0, 0.007],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 91.17313058478786, 'y': 81.72394044474862}},
#  {'data': {'id': 'wing margin, with Scer\\GAL4[NP7148]',
#    'label': 'wing margin, with Scer\\GAL4[NP7148]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 200.0, 0.044],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 80.02111715177128, 'y': 68.9815935634557}},
#  {'data': {'id': 'wing, with Scer\\GAL4[ptc-559.1]',
#    'label': 'wing, with Scer\\GAL4[ptc-559.1]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.02, 382.0, 0.084],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 89.7477762253684, 'y': 37.71423940024351}},
#  {'data': {'id': 'wing, with Scer\\GAL4[sd-SG29.1]',
#    'label': 'wing, with Scer\\GAL4[sd-SG29.1]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.027, 400.0, 0.088],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 82.41021151194953, 'y': 19.50422724022305}},
#  {'data': {'id': 'eye, with Scer\\GAL4[GMR.PU]',
#    'label': 'eye, with Scer\\GAL4[GMR.PU]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.002, 273.0, 0.06],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 95.89220986913814, 'y': 52.449376119456225}},
#  {'data': {'id': 'leg, with Scer\\GAL4[rn-GAL4]',
#    'label': 'leg, with Scer\\GAL4[rn-GAL4]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 23.0, 0.005],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 82.6079238330265, 'y': 79.91282404296803}},
#  {'data': {'id': 'tarsal segment, with Scer\\GAL4[rn-GAL4]',
#    'label': 'tarsal segment, with Scer\\GAL4[rn-GAL4]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 14.0, 0.003],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 10.556789258568426, 'y': 96.25142591168732}},
#  {'data': {'id': 'visible, with Scer\\GAL4[GMR.PU]',
#    'label': 'visible, with Scer\\GAL4[GMR.PU]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.042, 415.0, 0.091],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 97.820300452937, 'y': 66.53558604477627}},
#  {'data': {'id': 'visible, with Scer\\GAL4[rn-GAL4]',
#    'label': 'visible, with Scer\\GAL4[rn-GAL4]',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 7.0, 0.002],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 92.80655681914376, 'y': 34.22290706691995}},
#  {'data': {'id': 'abnormal courtship behavior',
#    'label': 'abnormal courtship behavior',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.016, 376.0, 0.083],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 94.39828528266985, 'y': 30.007492637274414}},
#  {'data': {'id': 'abnormal memory',
#    'label': 'abnormal memory',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.035, 410.0, 0.09],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 94.27991003173949, 'y': 37.50381416028551}},
#  {'data': {'id': 'flightless | recessive',
#    'label': 'flightless | recessive',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.014, 370.0, 0.081],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 6.77406949114072, 'y': 30.556578665317026}},
#  {'data': {'id': 'mesothoracic tarsal segment | distal | ectopic',
#    'label': 'mesothoracic tarsal segment | distal | ectopic',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 140.0, 0.031],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 95.34830693200121, 'y': 83.24651576999284}},
#  {'data': {'id': 'visible | homeotic | recessive',
#    'label': 'visible | homeotic | recessive',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.002, 265.0, 0.058],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 91.13301223531772, 'y': 75.9467113587958}},
#  {'data': {'id': 'antennal segment',
#    'label': 'antennal segment',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 236.0, 0.052],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 93.73601466727222, 'y': 4.826082962538836}},
#  {'data': {'id': 'mesothoracic tarsal segment',
#    'label': 'mesothoracic tarsal segment',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 223.0, 0.049],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 87.68418658762235, 'y': 42.23814853902671}},
#  {'data': {'id': 'metathoracic tarsal segment',
#    'label': 'metathoracic tarsal segment',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.003, 279.0, 0.061],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 97.38083320978778, 'y': 28.67996900133223}},
#  {'data': {'id': 'prothoracic tarsal segment',
#    'label': 'prothoracic tarsal segment',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 230.0, 0.051],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 6.8912082573099624, 'y': 50.50872348766995}},
#  {'data': {'id': 'female semi-sterile',
#    'label': 'female semi-sterile',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 1.0, 0.0],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 84.94595359851478, 'y': 51.687741374818394}},
#  {'data': {'id': 'male sterile',
#    'label': 'male sterile',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.01, 355.0, 0.078],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 6.810947074974154, 'y': 59.38467268707788}},
#  {'data': {'id': 'microchaeta',
#    'label': 'microchaeta',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.043, 416.0, 0.091],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 13.927138966604431, 'y': 78.53307147301744}},
#  {'data': {'id': 'sex comb',
#    'label': 'sex comb',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.017, 379.0, 0.083],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 10.264929742079186, 'y': 95.03882053202511}},
#  {'data': {'id': 'unguis | ectopic',
#    'label': 'unguis | ectopic',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.001, 211.0, 0.046],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 96.52401435962116, 'y': 20.53640471985505}},
#  {'data': {'id': 'leg joint',
#    'label': 'leg joint',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.005, 319.0, 0.07],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 92.36584616934871, 'y': 1.4999620028390281}},
#  {'data': {'id': 'partially lethal',
#    'label': 'partially lethal',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.078, 434.0, 0.095],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 92.85606466800846, 'y': 72.92866317777785}},
#  {'data': {'id': 'sterile',
#    'label': 'sterile',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.03, 405.0, 0.089],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 94.25250859497383, 'y': 55.087404703845976}},
#  {'data': {'id': 'antenna (with ss[134])',
#    'label': 'antenna (with ss[134])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 109.0, 0.024],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 17.129216768625003, 'y': 47.368215593726624}},
#  {'data': {'id': 'chaeta (with ss[134])',
#    'label': 'chaeta (with ss[134])',
#    'indent': 'phenotype',
#    'metadata': [None, None, 0.0, 110.0, 0.024],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
# ...
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 81.57175281861632, 'y': 53.01516309261564}},
#  {'data': {'id': 'Ahrr',
#    'label': 'Ahrr',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'mouse'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 36.78570261121064, 'y': 24.177481801354837}},
#  {'data': {'id': 'MP:0005377',
#    'label': 'MP:0005377',
#    'indent': 'phenotype',
#    'metadata': ['hearing/vestibular/ear phenotype',
#     ['MP:0000001'],
#     0.044,
#     9.0,
#     0.069],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 90.36434072879268, 'y': 57.48792572426949}},
#  {'data': {'id': 'MP:0004738',
#    'label': 'MP:0004738',
#    'indent': 'phenotype',
#    'metadata': ['abnormal auditory brainstem response',
#     ['MP:0006335'],
#     0.041,
#     8.0,
#     0.062],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 96.14625533276565, 'y': 97.63737734003223}},
#  {'data': {'id': 'MP:0002757',
#    'label': 'MP:0002757',
#    'indent': 'phenotype',
#    'metadata': ['decreased vertical activity', [], 0.024, 5.0, 0.038],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 99.44746109518394, 'y': 73.01349351171403}},
#  {'data': {'id': 'MP:0005561',
#    'label': 'MP:0005561',
#    'indent': 'phenotype',
#    'metadata': ['increased mean corpuscular hemoglobin',
#     ['MP:0001589'],
#     0.032,
#     7.0,
#     0.054],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 95.8438637263692, 'y': 1.6516037603693468}},
#  {'data': {'id': 'MP:0005564',
#    'label': 'MP:0005564',
#    'indent': 'phenotype',
#    'metadata': ['increased hemoglobin content',
#     ['MP:0005563'],
#     0.018,
#     3.0,
#     0.023],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 3.0235609617826187, 'y': 53.40039694962271}},
#  {'data': {'id': 'MP:0000186',
#    'label': 'MP:0000186',
#    'indent': 'phenotype',
#    'metadata': ['decreased circulating HDL cholesterol level',
#     [],
#     0.02,
#     4.0,
#     0.031],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 15.036439125995166, 'y': 82.33314290865734}},
#  {'data': {'id': 'MP:0001325',
#    'label': 'MP:0001325',
#    'indent': 'phenotype',
#    'metadata': ['abnormal retina morphology',
#     ['MP:0002864'],
#     0.03,
#     6.0,
#     0.046],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 90.84194329933501, 'y': 23.873141562996693}},
#  {'data': {'id': 'MP:0011396',
#    'label': 'MP:0011396',
#    'indent': 'phenotype',
#    'metadata': ['abnormal sleep behavior', ['MP:0004924'], 0.013, 2.0, 0.015],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 83.50649822049783, 'y': 40.336162297769874}},
#  {'data': {'id': 'Hsp90ab1',
#    'label': 'Hsp90ab1',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'mouse'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 31.090410896998527, 'y': 62.36589565669377}},
#  {'data': {'id': 'Ahr',
#    'label': 'Ahr',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'mouse'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 56.42528684942618, 'y': 71.24945653665966}},
#  {'data': {'id': 'Aip',
#    'label': 'Aip',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'mouse'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 55.90568992616199, 'y': 0.16431356995224577}},
#  {'data': {'id': 'Ptges3',
#    'label': 'Ptges3',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'mouse'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 21.685156366249316, 'y': 86.4307485294471}},
#  {'data': {'id': 'Arnt',
#    'label': 'Arnt',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'mouse'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 35.46943399524945, 'y': 77.13090830514344}},
#  {'data': {'id': 'Arnt2',
#    'label': 'Arnt2',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'mouse'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 59.857980491273025, 'y': 44.903795279488115}},
#  {'data': {'id': 'ahrra',
#    'label': 'ahrra',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 62.92212060918392, 'y': 78.69043747362649}},
#  {'data': {'id': 'ahrrb',
#    'label': 'ahrrb',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 38.66458327054353, 'y': 68.2571835004774}},
#  {'data': {'id': 'hsp90ab1',
#    'label': 'hsp90ab1',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 36.486744966130274, 'y': 12.7821787008351}},
#  {'data': {'id': 'ahr1a',
#    'label': 'ahr1a',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 22.223919710146337, 'y': 88.72740117109728}},
#  {'data': {'id': 'aip',
#    'label': 'aip',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 67.55401213469985, 'y': 31.014999411751866}},
#  {'data': {'id': 'ptges3a',
#    'label': 'ptges3a',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 29.045329528041528, 'y': 18.8741666415015}},
#  {'data': {'id': 'ptges3b',
#    'label': 'ptges3b',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 75.85543600743961, 'y': 26.794311760613976}},
#  {'data': {'id': 'WBGene00000096',
#    'label': 'WBGene00000096',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'celegans'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 71.7318283387965, 'y': 92.25275173858695}},
#  {'data': {'id': 'WBPhenotype:0000625',
#    'label': 'WBPhenotype:0000625',
#    'indent': 'phenotype',
#    'metadata': ['synaptogenesis variant',
#     ['WBPhenotype:0000623'],
#     0.004,
#     7.0,
#     0.012],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 89.21817465778018, 'y': 26.74554747122616}},
#  {'data': {'id': 'WBPhenotype:0001331',
#    'label': 'WBPhenotype:0001331',
#    'indent': 'phenotype',
#    'metadata': ['motor neuron morphology variant',
#     ['WBPhenotype:0000905'],
#     0.0,
#     2.0,
#     0.004],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 12.10754904376147, 'y': 49.98357363883348}},
#  {'data': {'id': 'WBPhenotype:0001510',
#    'label': 'WBPhenotype:0001510',
#    'indent': 'phenotype',
#    'metadata': ['neuronal cell fate specification variant',
#     ['WBPhenotype:0000216'],
#     0.015,
#     15.0,
#     0.026],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 80.18244905165756, 'y': 2.6258949535642784}},
#  {'data': {'id': 'WBPhenotype:0002261',
#    'label': 'WBPhenotype:0002261',
#    'indent': 'phenotype',
#    'metadata': ['neurite connectivity defective',
#     ['WBPhenotype:0000623'],
#     0.0,
#     1.0,
#     0.002],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 4.587323999269975, 'y': 67.23990863253073}},
#  {'data': {'id': 'WBGene00000915',
#    'label': 'WBGene00000915',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'celegans'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 77.24428992338879, 'y': 33.58207640368695}},
#  {'data': {'id': 'WBPhenotype:0000012',
#    'label': 'WBPhenotype:0000012',
#    'indent': 'phenotype',
#    'metadata': ['dauer constitutive',
#     ['WBPhenotype:0000637'],
#     0.002,
#     5.0,
#     0.009],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 1.7147249389789931, 'y': 96.3891872058471}},
#  {'data': {'id': 'WBPhenotype:0000127',
#    'label': 'WBPhenotype:0000127',
#    'indent': 'phenotype',
#    'metadata': ['dauer recovery variant',
#     ['WBPhenotype:0000159'],
#     0.007,
#     12.0,
#     0.021],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 86.26585127199561, 'y': 84.38871605531226}},
#  {'data': {'id': 'WBPhenotype:0000646',
#    'label': 'WBPhenotype:0000646',
#    'indent': 'phenotype',
#    'metadata': ['sluggish', ['WBPhenotype:0001213'], 0.005, 9.0, 0.016],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 10.138330485136702, 'y': 15.087434756841722}},
#  {'data': {'id': 'WBPhenotype:0001048',
#    'label': 'WBPhenotype:0001048',
#    'indent': 'phenotype',
#    'metadata': ['odorant chemosensory response variant',
#     ['WBPhenotype:0001040'],
#     0.005,
#     8.0,
#     0.014],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 90.13509990545042, 'y': 84.19515059358062}},
#  {'data': {'id': 'WBPhenotype:0001434',
#    'label': 'WBPhenotype:0001434',
#    'indent': 'phenotype',
#    'metadata': ['chemotaxis variant',
#     ['WBPhenotype:0001040'],
#     0.0,
#     3.0,
#     0.005],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 93.24656249958711, 'y': 83.02470325717258}},
#  {'data': {'id': 'WBPhenotype:0000644',
#    'label': 'WBPhenotype:0000644',
#    'indent': 'phenotype',
#    'metadata': ['paralyzed', ['WBPhenotype:0001213'], 0.003, 6.0, 0.011],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 18.834396390024956, 'y': 57.851202345900134}},
#  {'data': {'id': 'WBPhenotype:0001012',
#    'label': 'WBPhenotype:0001012',
#    'indent': 'phenotype',
#    'metadata': ['organism pathogen response variant',
#     ['WBPhenotype:0000738'],
#     0.023,
#     16.0,
#     0.028],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 81.33324867532181, 'y': 80.95246539911349}},
#  {'data': {'id': 'WBPhenotype:0000055',
#    'label': 'WBPhenotype:0000055',
#    'indent': 'phenotype',
#    'metadata': ['early larval arrest',
#     ['WBPhenotype:0000059'],
#     0.006,
#     11.0,
#     0.019],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 13.979072924089543, 'y': 3.3410446341763933}},
#  {'data': {'id': 'WBPhenotype:0000668',
#    'label': 'WBPhenotype:0000668',
#    'indent': 'phenotype',
#    'metadata': ['endomitotic oocytes',
#     ['WBPhenotype:0001260'],
#     0.025,
#     17.0,
#     0.03],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 4.647232272121462, 'y': 66.19084980316254}},
#  {'data': {'id': 'WBPhenotype:0001943',
#    'label': 'WBPhenotype:0001943',
#    'indent': 'phenotype',
#    'metadata': ['rachis wide', ['WBPhenotype:0001940'], 0.034, 20.0, 0.035],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 97.36313515719044, 'y': 15.788077380311949}},
#  {'data': {'id': 'WBPhenotype:0001947',
#    'label': 'WBPhenotype:0001947',
#    'indent': 'phenotype',
#    'metadata': ['diplotene progression during oogenesis variant',
#     ['WBPhenotype:0001824'],
#     0.026,
#     18.0,
#     0.032],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 4.522930527988118, 'y': 6.146619048683732}},
#  {'data': {'id': 'WBPhenotype:0001349',
#    'label': 'WBPhenotype:0001349',
#    'indent': 'phenotype',
#    'metadata': ['protein phosphorylation variant',
#     ['WBPhenotype:0001382'],
#     0.005,
#     10.0,
#     0.018],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 0.10688790667927606, 'y': 6.836462589352854}},
#  {'data': {'id': 'WBPhenotype:0001925',
#    'label': 'WBPhenotype:0001925',
#    'indent': 'phenotype',
#    'metadata': ['oocytes disorganized',
#     ['WBPhenotype:0001260'],
#     0.035,
#     21.0,
#     0.037],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 97.15541648297355, 'y': 43.26675053237994}},
#  {'data': {'id': 'WBGene00016966',
#    'label': 'WBGene00016966',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'celegans'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 61.20175012183974, 'y': 82.64805618754896}},
#  {'data': {'id': 'nan',
#    'label': 'nan',
#    'indent': 'phenotype',
#    'metadata': None,
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 19.039396605533444, 'y': 24.562425996449345}},
#  {'data': {'id': 'WBGene00022599',
#    'label': 'WBGene00022599',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'celegans'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 61.39955344648559, 'y': 39.53958222146498}},
#  {'data': {'id': 'WBPhenotype:0000295',
#    'label': 'WBPhenotype:0000295',
#    'indent': 'phenotype',
#    'metadata': ['thermotolerance increased',
#     ['WBPhenotype:0000146'],
#     0.011,
#     14.0,
#     0.025],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 88.2795990513529, 'y': 75.12592764072154}},
#  {'data': {'id': 'WBPhenotype:0001789',
#    'label': 'WBPhenotype:0001789',
#    'indent': 'phenotype',
#    'metadata': ['temperature influenced life span variant',
#     ['WBPhenotype:0000039', 'WBPhenotype:0000146'],
#     0.002,
#     4.0,
#     0.007],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 97.93211099553442, 'y': 15.629768630792483}},
#  {'data': {'id': 'WBPhenotype:0001403',
#    'label': 'WBPhenotype:0001403',
#    'indent': 'phenotype',
#    'metadata': ['antibody subcellular localization variant',
#     ['WBPhenotype:0000424'],
#     0.032,
#     19.0,
#     0.033],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 93.34241905279268, 'y': 76.63880076304304}},
#  {'data': {'id': 'WBGene00000095',
#    'label': 'WBGene00000095',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'celegans'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 59.16782324839741, 'y': 12.823417117507807}},
#  {'data': {'id': 'WBPhenotype:0001989',
#    'label': 'WBPhenotype:0001989',
#    'indent': 'phenotype',
#    'metadata': ['hypoxia hypersensitive',
#     ['WBPhenotype:0002423'],
#     0.007,
#     13.0,
#     0.023],
#    'size': 1,
#    'fontsize': '0.5px'},
#   'classes': 'purple',
#   'selectable': True,
#   'grabbable': False,
#   'position': {'x': 93.34266956802091, 'y': 36.787163494252184}}]

# %%
new_test = []

for i in new_element1:
    if i.get('data').get('organism') == 'zebrafish':
        new_test.append(i)
new_test
# Out:
# [{'data': {'id': 'arnt',
#    'label': 'arnt',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 41.83495621677152, 'y': 48.064603068407585}},
#  {'data': {'id': 'arnt2',
#    'label': 'arnt2',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 39.55501146034899, 'y': 64.72956443328935}},
#  {'data': {'id': 'arnt2',
#    'label': 'arnt2',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 39.55501146034899, 'y': 64.72956443328935}},
#  {'data': {'id': 'ahrra',
#    'label': 'ahrra',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 62.92212060918392, 'y': 78.69043747362649}},
#  {'data': {'id': 'ahrrb',
#    'label': 'ahrrb',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 38.66458327054353, 'y': 68.2571835004774}},
#  {'data': {'id': 'hsp90ab1',
#    'label': 'hsp90ab1',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 36.486744966130274, 'y': 12.7821787008351}},
#  {'data': {'id': 'ahr1a',
#    'label': 'ahr1a',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 22.223919710146337, 'y': 88.72740117109728}},
#  {'data': {'id': 'aip',
#    'label': 'aip',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 67.55401213469985, 'y': 31.014999411751866}},
#  {'data': {'id': 'ptges3a',
#    'label': 'ptges3a',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 29.045329528041528, 'y': 18.8741666415015}},
#  {'data': {'id': 'ptges3b',
#    'label': 'ptges3b',
#    'indent': 'ortholog',
#    'size': 2,
#    'fontsize': '1px',
#    'organism': 'zebrafish'},
#   'classes': 'ortholog',
#   'selectable': True,
#   'position': {'x': 75.85543600743961, 'y': 26.794311760613976}}]

# %% [markdown]
# ## Define organism and colors

# %%
#organisms list:
organism = ['dmelanogaster','mouse','celegans','zebrafish']
# https://plotly.com/python/discrete-color/
col_swatch = [px.colors.qualitative.Safe[8], px.colors.qualitative.Set1[2],
              px.colors.qualitative.Set1[7],px.colors.qualitative.Set1[4]]

# %% [markdown]
# ## Function to caluculate the number of phenotypes

# %%
# calculate the right phenotype number
def calculate_no_phenotypes (df):
    no_celegans = (df.groupby(['Organism']).count())['Enriched_Phenotypes'][0]
    no_dmelanogaster = (df.groupby(['Organism']).count())['Enriched_Phenotypes'][1]
    no_mouse = (df.groupby(['Organism']).count())['Enriched_Phenotypes'][2]
    no_zebrafish = (df.groupby(['Organism']).count())['Enriched_Phenotypes'][3]
    totalPhenotype = [no_celegans,no_dmelanogaster,no_mouse,no_zebrafish]
    org_totalPhenotype = dict(zip(organism,totalPhenotype))
    return org_totalPhenotype

# %%
org_totalPhenotype = calculate_no_phenotypes(upper_df1)
org_totalPhenotype
# Out:
# {'dmelanogaster': 217, 'mouse': 350, 'celegans': 57, 'zebrafish': 0}

# %%
org_totalPhenotype_1 = calculate_no_phenotypes(gene_df_1)
org_totalPhenotype_1
# Out:
# {'dmelanogaster': 330, 'mouse': 8634, 'celegans': 48, 'zebrafish': 9}

# %%
org_totalPhenotype_2 = calculate_no_phenotypes(gene_df_2)
org_totalPhenotype_2
# Out:
# {'dmelanogaster': 865, 'mouse': 13523, 'celegans': 0, 'zebrafish': 0}

# %%
org_totalPhenotype_3 = calculate_no_phenotypes(gene_df_3)
org_totalPhenotype_3
# Out:
# {'dmelanogaster': 5136, 'mouse': 57023, 'celegans': 2, 'zebrafish': 0}

# %%
org_totalPhenotype_4 = calculate_no_phenotypes(gene_df_4)
org_totalPhenotype_4
# Out:
# {'dmelanogaster': 865, 'mouse': 13523, 'celegans': 0, 'zebrafish': 0}

# %% [markdown]
# ## Define app:

# %%
graph_stylesheet = [
    # {
    #     'selector': organism[i],       # colours based on organism
    #     'style': {"background-color": col_swatch[i],
    #               "line-color": col_swatch[i]
    #               },
    # }
    # for i in range(len(organism))

# colours based on organism
    {
        'selector': '[organism *= "dmelanogaster"]',
        'style': {
            'background-color': col_swatch[0],
            'line-colour': col_swatch[0],
        }
    },
    {
        'selector': '[organism *= "mouse"]',
        'style': {
            'background-color': col_swatch[1],
            'line-colour': col_swatch[1],
        }
    },
    {
        'selector': '[organism *= "celegans"]',
        'style': {
            'background-color': col_swatch[2],
            'line-colour': col_swatch[2],
        }
    },
    {
        'selector': '[organism *= "zebrafish"]',
        'style': {
            'background-color': col_swatch[3],
            'line-colour': col_swatch[3],
        }
    }
]

graph_stylesheet += [
    {
        'selector': 'nodes',
        'style': {
            'content': 'data(label)',
            'width': 'data(size)',
            'height': 'data(size)',
            "curve-style": "bezier",
            'font-size': 'data(fontsize)',
        }
    },
    {
        'selector': 'edges',
        'style': {
            'width': 'data(width)',
            'line-color': 'data(color)',
        }
    },
    {
        'selector': '.purple',
        'style': {
            'background-color': '#C918F3',
            'line-color': '#C918F3'
        }
    },

    {
        'selector': '.blue',
        'style': {'background-color': '#18B6F3',
                  'line-color': '#18B6F3'
                  }
    }

]

# %%
# Define app
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])
# server = app.server

# %%
navbar = dbc.NavbarSimple(
    children=[
        dbc.NavItem(
            dbc.NavLink(
                "Article",
                href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5829367/",
            )
        ),
        dbc.NavItem(
            dbc.NavLink(
                "Source Code",
                href="https://github.com/ivanajanickova/DARTpaths-vis",
            )
        ),
    ],
    brand="Dart - Translation of Genotype to Phenotype by a Hierarchy of Model Organism - simple demo", #title
    brand_href="#",
    color="dark",
    dark=True,
)

# %%
topics_html = list()
for topic_html in [
    html.Span([str(i+1) + ": " + organism[i]], style={"color": col_swatch[i]})
    for i in range(len(organism))
]:
    topics_html.append(topic_html)
    topics_html.append(html.Br())

# %% [markdown]
# ## Body layout

# %%
body_layout = dbc.Container(
    [
        dbc.Row(
            [
                dbc.Col(
                    [
                        dcc.Markdown(
                            f"""
                -----
                ##### Description:
                -----
                For this demonstration, phenotypes from 4 model organism were used to visualize
                the relationship between phenotypes from different organism related to a particular human
                pathway. The pathways are preference from [REACTOME](https://reactome.org/PathwayBrowser/)
                Phenotype from each organism is shown in different color on the map, as shown on the right.
                """
                        )
                    ],
                    sm=12,
                    md=8,
                ),
                dbc.Col(
                    [
                        dcc.Markdown(
                            """
                -----
                ##### Model oganisms:
                -----
                """
                        ),
                        html.Div(
                            topics_html,
                            style={
                                "fontSize": 11,
                                "height": "100px",
                                "overflow": "auto",
                            },
                        ),
                    ],
                    sm=12,
                    md=4,
                )
            ]
        ),
        dbc.Row(
            [
                dcc.Markdown(
                    """
            -----
            ##### Node representation
            There are three kinds of node in the graph. The biggest nodes in the center indicate human genes in a chosen 
            pathway. These nodes are linked directly with the second type of node which indicate orthologs from a model 
            organism. Node color indicates which organism the orthologs belong to. 
            
            The third type of node in two sides is the phenotype enrichment of organism model
            
            The edges show the relationship of 1. phenotypes and its related ortholog gene in organism 2. ortholog genes in 
            organism and its human gene in the same molecular pathway in Reactome.

            Use the filters to choose the phenotype with:
            * certain numbers of pathway/ pathway level 
            * certain numbers of model organism you want to investigate
            
            The slider is used to explore 3 level of visualisation: human gene only, human gene and orthologs or the whole graph. Toggle to explore different visualisation options.
            
            -----
            """
                )
            ]
        ),
        dbc.Row(
            [
                dbc.Col(
                    [
                        dbc.Row(
                            [
                                cyto.Cytoscape(
                                    id='cytoscape-phenotype',
                                    layout={"name": "preset"},
                                    style={"width": "100%", "height": "800px"},
                                    elements= element,   #change
                                    stylesheet=graph_stylesheet,
                                    #style={'width': '100%', 'height': '95vh'}
                                    minZoom = 0.6
                                )
                            ]
                        ),
                        dbc.Row(
                            [
                                dbc.Alert(
                                    id='phenotype-data',
                                    children='Click on a node to see its details here',
                                    color='secondary'
                                )
                            ]
                        )
                    ],
                    sm=12,
                    md=8
                ),
                dbc.Col(
                    [
                        dbc.Label('Search phenotype for a gene: ', html_for='gene_search'),
                        dbc.Input(type='search', id='gene_search', placeholder="Enter a gene ID here"),
                        dbc.FormText('The gene is not available in the pathway', color='secondary'),
                        html.Div(style={'padding': 20}), #Space

                        dbc.Row(
                            [
                                dbc.Col(
                                    [
                                        html.H4(dbc.Badge(
                                            "Level of pathway(s):",
                                            color="success",
                                            className="ms-1",

                                        )),

                                        dcc.Dropdown(
                                            id="pathway_level",
                                            #options=[{"label": k, "value": k} for k in range(1,3)],
                                            options=[{"label": 'lower level', "value": 1},{"label": 'upper level', "value": 2}],
                                            clearable=False,
                                            value= 2,
                                            style={"width": "150px"},
                                    )
                                    ]),
                                dbc.Col(
                                    [
                                        #Irene
                                        dbc.Badge(           # dropdown to choose pathway of lowest level
                                            "Available sub-pathway:    ",
                                            color="white",
                                            text_color="muted",
                                            class_name="border me-1",
                                        ),
                                        html.Div(style={'padding': 7}), #Space
                                        dcc.Dropdown(
                                            id="Lowest_Level",
                                            options=[{"label": name , "value": name }
                                                     for name in path_list   #change
                                                    ],
                                            clearable=False,
                                            value = path_list[0],             # 'AHR'
                                            style={"width": "187px"},
                                        )])]),

                        html.H4(dbc.Badge(
                            "Model organism(s):", color="success", className="mr-1"
                        )),
                        dcc.Dropdown(
                            id="organism_dropdown",
                            options=[{"label": i + " (" + str(v)+ " phenotype(s))", "value": i} for i, v in org_totalPhenotype.items()],
                            value= [{"label": i + " (" + str(v)+ " phenotype(s))", "value": i} for i, v in org_totalPhenotype.items()] ,    #check??
                            #value= org_totalPhenotype.keys(),   #if change will cause layout error
                            multi=True,
                            style={"width": "100%"},
                        ),
                        html.Div(style={'padding': 7}),
                        dbc.Button("Search", id="search-button", className="me-2", n_clicks=0, size="sm",color="secondary"),
                        html.Span(id="search-status", style={"verticalAlign": "middle"}),
                        html.Div(style={'padding': 20}),  #Space

                        html.H4(dbc.Badge(
                            "Choose level of visualisation:", color="success", className="mr-1"
                        )),
                        html.Div(style={'padding': 10}), #Space
                        dcc.Slider(
                            id='detail_slider',
                            min=1,
                            max=3,
                            value=3,
                            marks={1: "human_gene",2:"organism_ortholog", 3:"organism_phenotype"},
                            step=1
                        )
                    ]
                )
                ]
        )

    ]
)

# %%
org_totalPhenotype.items()
# Out:
# dict_items([('dmelanogaster', 217), ('mouse', 350), ('celegans', 57), ('zebrafish', 0)])

# %%
app.layout = html.Div([navbar, body_layout])

# %% [markdown]
# ## Dash Callbacks

# %% [markdown]
# ### Click on a node to see its details here

# %%
# call back Node information -----------------
@app.callback(
    Output('phenotype-data', 'children'),
    [Input('cytoscape-phenotype', 'tapNodeData')]
)
def display_nodeData(data):
    contents = 'Click on a node to see its details here'
    if data:
        contents = []
        if data.get('indent') == 'phenotype':
            contents.append(html.H5('Phenotype: ' + data.get('label')))
            contents.append(html.P('Hierchically related phenotype(s): ' + str(data.get('metadata')[1])))
            contents.append(html.P('Phenotype enrichment Q-value: ' + str(data.get('metadata')[2])))
            contents.append(html.P('Phenotype enrichment P-value: ' + str(data.get('metadata')[4])))
            return contents
        elif data.get('indent') == 'gene':
            contents.append(html.H5('Gene ID: ' + data.get('label')))
            return contents
        elif data.get('indent') == 'ortholog':
            contents.append(html.H5('Ortholog ID: ' + data.get('label')))
            contents.append(html.P('Organism: ' + data.get('organism')))
            return contents
    else:
        return contents

# %% [markdown]
# ### Search phenotype for a gene:

# %%
#@app.callback(
#     Output('phenotype-data', 'children'),
#     [Input('cytoscape-phenotype', 'tapNodeData')]
# )
# def display_phenotype(data):
#     contents = 'Click on a node to see its details here'
#     if data:
#         contents = []
#         #contents.append(html.H5('Phenotype: ' + str(data.get('metadata')[0])))
#         contents.append(html.H5('Phenotype: ' + data.get('id')))
#         contents.append(html.P('Hierchically related phenotype(s): ' + str(data.get('metadata')[1])))
#         contents.append(html.P('Phenotype enrichment Q-value: ' + str(data.get('metadata')[3])))
#         contents.append(html.P('Phenotype enrichment P-value: ' + str(data.get('metadata')[4])))
#         return contents
#     else:
#         return contents

# %% [markdown]
# ### Level of pathway:

# %%
@app.callback(
    [Output('cytoscape-phenotype', "elements"),
     Output('Lowest_Level','options'),
     Output('organism_dropdown', 'value'),
     ],
    [Input('pathway_level', 'value')]
)
def filter_nodes_1(value):
    if value == 1:
        options = [{"label": name, "value": name}
                   for name in path_list]   # change
        value = [{"label": i + " (" + str(v) + " phenotype(s))", "value": i} for i, v in org_totalPhenotype_1.items()]
        return new_element1, options, value
    if value == 2:
        options = [{"label": name , "value": name } for name in ['']] #check
        value = [{"label": i + " (" + str(v) + " phenotype(s))", "value": i} for i, v in org_totalPhenotype.items()]
        return element, options, value

# %% [markdown]
# ### Level of lowest pathway:

# %%
#@app.callback(
#    [Output('cytoscape-phenotype', "elements"),
#     Output('organism_dropdown', 'value'),
#     ],
#    [Input('Lowest_Level', 'value')]
#)

#def filter_nodes_2(value):
#    if value == path_list[0]:
#        value = [{"label": i + " (" + str(v) + " phenotype(s))", "value": i} for i, v in org_totalPhenotype_1.items()]
#        return new_element1, value
#    if value == path_list[1]:
#        value = [{"label": i + " (" + str(v) + " phenotype(s))", "value": i} for i, v in org_totalPhenotype_2.items()]
#        return new_element2, value
#    if value == path_list[2]:
#        value = [{"label": i + " (" + str(v) + " phenotype(s))", "value": i} for i, v in org_totalPhenotype_3.items()]
#        return new_element3, value
#    if value == path_list[3]:
#        value = [{"label": i + " (" + str(v) + " phenotype(s))", "value": i} for i, v in org_totalPhenotype_4.items()]
#        return new_element4, value

# %% [markdown]
# ### Model organism(s):

# %%
@app.callback (
    Output('cytoscape-phenotype', "elements"),
    [Input('organism_dropdown', 'value'), 
    Input('Lowest_Level', 'value')]
)

def select_organism(value1, value2):
    new_elements = []
    if value1 == organism[0]:
        if value2 == path_list[0]:
            for i in new_elements1.get('data').get('organism') == 'dmelanogaster':
                new_elements.append(i) 
        if value2 == path_list[1]:
            for i in new_elements1.get('data').get('organism') == 'mouse':
                new_elements.append(i)
        if value2 == path_list[2]:
            for i in new_elements1.get('data').get('organism') == 'celegans':
                new_elements.append(i)
        if value2 == path_list[3]:
            for i in new_elements1.get('data').get('organism') == 'zebrafish':
                new_elements.append(i)
    if value1 == organism[1]:
        if value2 == path_list[0]:
            for i in new_elements2.get('data').get('organism') == 'dmelanogaster':
                new_elements.append(i) 
        if value2 == path_list[1]:
            for i in new_elements2.get('data').get('organism') == 'mouse':
                new_elements.append(i)
        if value2 == path_list[2]:
            for i in new_elements2.get('data').get('organism') == 'celegans':
                new_elements.append(i)
        if value2 == path_list[3]:
            for i in new_elements2.get('data').get('organism') == 'zebrafish':
                new_elements.append(i)
    if value1 == organism[2]:
        if value2 == path_list[0]:
            for i in new_elements3.get('data').get('organism') == 'dmelanogaster':
                new_elements.append(i) 
        if value2 == path_list[1]:
            for i in new_elements3.get('data').get('organism') == 'mouse':
                new_elements.append(i)
        if value2 == path_list[2]:
            for i in new_elements3.get('data').get('organism') == 'celegans':
                new_elements.append(i)
        if value2 == path_list[3]:
            for i in new_elements3.get('data').get('organism') == 'zebrafish':
                new_elements.append(i)
    if value1 == organism[3]:
        if value2 == path_list[0]:
            for i in new_elements4.get('data').get('organism') == 'dmelanogaster':
                new_elements.append(i) 
        if value2 == path_list[1]:
            for i in new_elements4.get('data').get('organism') == 'mouse':
                new_elements.append(i)
        if value2 == path_list[2]:
            for i in new_elements4.get('data').get('organism') == 'celegans':
                new_elements.append(i)
        if value2 == path_list[3]:
            for i in new_elements4.get('data').get('organism') == 'zebrafish':
                new_elements.append(i)
    return new_elements
#-----------------------------------------------

# call back Slider + Dropdown -----------------
# @app.callback(
#     Output('cytoscape-phenotype', "elements"),
#     [
#         Input('pathway_level', 'value'),
#         Input('organism_dropdown', 'value'),
#         Input('detail_slider', 'value'),
#     ]
# )
# def filter_nodes(pathway_level, organism_list, detail_slider):
#     ctx = dash.callback_context
#     if not ctx.triggered:
#         return element
#
#     else:
#         trigger_id = ctx.triggered[0]['prop_id'].split(".")[0]
#         val = ctx.triggered[0]['value'].split(".")[0]
#
#         if trigger_id == 'pathway_level':
#             pathway = val
#             df = gene_df1 if val == 1 else gene_df2
#         elif trigger_id == 'organism_dropdown':


#----------------------------------------------
# @app.callback(
#     Output('cytoscape-phenotype', 'elements'),
#     [Input('pathway_level', 'value'),
#      Input('organism_dropdown', 'value')]
# )
# def filter_nodes(pathway_level):
#     if pathway_level == 1:
#         metadata1 = db_retrieve.select_from_metadata("AHR")
#         new_nodes, new_edges = load_info_to_graph(gene_df_1, metadata1, N_genes_1)
#         new_element = new_edges + new_nodes
#         return new_element
#
#     return element
#---------------------------------------------

# %% [markdown]
# ### Running the app:

# %%
if __name__ == '__main__':
    app.run_server(debug=False)  # set false so you can load bigger networks
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
